# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread('img logo.png')

# %%
plt.imshow(img)

# %%
cv2.imshow('benz Logo',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray_img = cv2.imread('img logo.png',cv2.IMREAD_GRAYSCALE)
cv2.imshow('Gray Logo',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
originalImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(originalImg)
